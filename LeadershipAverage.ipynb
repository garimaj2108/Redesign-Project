# %%
import pandas as pd
import numpy as np

# %%
leadership_average = pd.read_csv('/Users/garimajain/Desktop/Leadership_Average_2.csv')

# %%
df1 = leadership_average[['Facebook','LinkedIn','Pinterest','Tumblr','Twitter','Google','Apple','eBay']].iloc[0:]

# %%
df1['Leadership Average'] = df1.mean(axis=1)

# %%
df1.round()
# Out:
#     Facebook LinkedIn  Pinterest  Tumblr  Twitter Google  Apple eBay  \
# 0         23       25       19.0      23       21     21     28   28
# 1         77       75       81.0      77       79     79     72   72
# 2         74       65        NaN      63       72     72     64   72
# 3         19       28        NaN      24       24     23     21   23
# 4          4        4        NaN       6        0      1      6    2
# 5          2        1        NaN       3        2      1      3    2
# 6          1        3        NaN       2        0      1      0    1
# 7          0       <1        NaN       2        2     <1      6   <1
# 8         23       30       16.0      24       22     22     28   29
# 9         77       70       84.0      76       78     78     72   71
# 10        73       63       47.0      73       72     72     63   71
# 11        21       30       42.0      19       28     23     21   24
# 12         3        4        0.0       2        0      1      6    2
# ...

# %%
df1.to_csv('LeadershipAverage.csv', index=False, encoding='utf-8')
