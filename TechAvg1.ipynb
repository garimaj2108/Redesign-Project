# %%
import pandas as pd
import numpy as np

# %%
tech_average = pd.read_csv('/Users/garimajain/Desktop/Tech_Average_2.csv')

# %%
df1 = tech_average[['Facebook','LinkedIn','Pinterest','Tumblr','Twitter','Google','Apple','eBay']].iloc[0:]

# %%
df1['Tech Average'] = df1.mean(axis=1)

# %%
df1.round()
# Out:
#     Facebook LinkedIn  Pinterest  Tumblr  Twitter Google  Apple eBay  \
# 0         15       17       21.0      15       10     17     20   24
# 1         85       83       79.0      85       90     83     80   76
# 2         53       34        NaN      35       58     60     54   40
# 3         41       60        NaN      57       34     33     23   55
# 4          3        3        NaN       3        3      2      7    2
# 5          1        1        NaN       1        1      1      6    2
# 6          2        1        NaN       1        2      3      2    1
# 7          0       <1        NaN       2        2     <1      8   <1
# 8         16       18       21.0      16       13     18     21   24
# 9         84       82       79.0      84       87     82     79   76
# 10        51       34       35.0      31       56     59     53   39
# 11        43       61       60.0      61       37     35     25   56
# 12         3        3        2.0       3        3      2      8    2
# ...

# %%
df1.to_csv('TechAverage1.csv', index=False, encoding='utf-8')
