# %%
import pandas as pd
import numpy as np

# %%
overall_average = pd.read_csv('/Users/garimajain/Desktop/Overall_Average_2.csv')

# %%
overall_average
# Out:
#            Gender / Race  Year  Facebook LinkedIn  Pinterest  Tumblr  Twitter  \
# 0               Female %  2014        31       39         40      37       30
# 1                 Male %  2014        69       61         60      63       70
# 2                White %  2014        57       53         50      50       59
# 3                Asian %  2014        34       38         42      39       29
# 4               Latino %  2014         4        4          2       4        3
# 5                Black %  2014         2        2          1       2        2
# 6               Multi %   2014         3        2          0       2        3
# 7   Other & Undeclared %  2014         0        1          5       2        4
# 8               Female %  2015        32       42         42      37       30
# 9                 Male %  2015        68       58         58      62       70
# 10               White %  2015        55       56         49      50       59
# ...

# %%
df1 = overall_average[['Facebook','LinkedIn','Pinterest','Tumblr','Twitter','Google','Apple','eBay']].iloc[0:]

# %%
df1['Overall Average'] = df1.mean(axis=1)

# %%
df1.round()
# Out:
#            Gender / Race  Facebook LinkedIn  Pinterest  Tumblr  Twitter  \
# 0               Female %        31       39         40      37       30
# 1                 Male %        69       61         60      63       70
# 2                White %        57       53         50      50       59
# 3                Asian %        34       38         42      39       29
# 4               Latino %         4        4          2       4        3
# 5                Black %         2        2          1       2        2
# 6               Multi %          3        2          0       2        3
# 7   Other & Undeclared %         0        1          5       2        4
# 8               Female %        32       42         42      37       30
# 9                 Male %        68       58         58      62       70
# 10               White %        55       56         49      50       59
# 11               Asian %        36       37         43      39       29
# ...

# %%
df1.to_csv('OverallAverage1.csv', index=False, encoding='utf-8')
