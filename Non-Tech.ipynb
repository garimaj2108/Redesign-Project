# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv('/Users/garimajain/Desktop/Non-Tech_Diversity.csv')

# %%
df
# Out:
#               Company  Year  Female %  Male %  % White  % Asian  % Latino  \
# 0            Facebook  2014        47      53     63.0     24.0       6.0
# 1            LinkedIn  2014        47      53     63.0     26.0       5.0
# 2           Pinterest  2014        34      66      NaN      NaN       NaN
# 3              Tumblr  2014        52      47     63.0     24.0       6.0
# 4             Twitter  2014        50      50     60.0     23.0       3.0
# 5              Google  2014        48      52     65.0     23.0       4.0
# 6               Apple  2014        35      65     56.0     14.0       9.0
# 7                eBay  2014        49      51     70.0     11.0       7.0
# 8    Non-Tech Average  2014        45      55     63.0     21.0       6.0
# 9            Facebook  2015        48      52     62.0     24.0       7.0
# 10           LinkedIn  2015        50      50     66.0     25.0       4.0
# 11          Pinterest  2015        34      66     67.0     22.0       3.0
# ...

# %%
df.to_csv('Non-Tech.csv', index=False, encoding='utf-8')
